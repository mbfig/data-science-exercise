# %%
# % matplotlib inline
import pandas as pd
import math
import numpy as np
from datetime import timedelta
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from fbprophet import Prophet

# %%
training_data = pd.read_csv('../dataset/usage_train.csv', date_parser = pd.to_datetime)

# %% [markdown]
# split the data

# %%
training_data['datetime'] = pd.DatetimeIndex(training_data['datetime'])
training_data['weekofyear']= training_data.datetime.apply(lambda x: x.weekofyear)
training_data = training_data.rename(columns = {'datetime': 'ds','usage': 'y'})

# %%
n_index = training_data.ds.nunique()
idx_split = math.floor(n_index*0.99)
list_dates = list(training_data.ds.unique())
threshold = list_dates[idx_split]
print(list_dates[idx_split])
# Out:
# 2013-12-06T19:00:00.000000000

# %%
idx_split
# Out:
# 17012

# %%
df_training = training_data[training_data.weekofyear <= idx_split]
df_test = training_data[training_data.weekofyear > idx_split]

# %%
df_training.id.unique()
# Out:
# array(['MAC003828', 'MAC003685', 'MAC005415', 'MAC000085', 'MAC004671',
#        'MAC004218', 'MAC001757', 'MAC004166', 'MAC000246', 'MAC000094'],
#       dtype=object)

# %% [markdown]
# #### Create model for a house

# %%
df_house = df_training[df_training.id == 'MAC000246']
df_house_test = df_test[df_test.id == 'MAC000246']

# %%
df_house.head(5)
# Out:
#                id                  ds      y  weekofyear
# 137472  MAC000246 2012-12-17 09:00:00  0.057          51
# 137473  MAC000246 2012-12-17 09:30:00  0.055          51
# 137474  MAC000246 2012-12-17 10:00:00  0.064          51
# 137475  MAC000246 2012-12-17 10:30:00  0.049          51
# 137476  MAC000246 2012-12-17 11:00:00  0.025          51

# %%
model = Prophet(interval_width = 0.95)
model.fit(df_house[['ds','y']])
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /anaconda3/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %% [markdown]
# #### Predictions

# %%
future_dates = df_house_test[['ds']]

# %%
future_dates.ds.nunique()
# Out:
# 336

# %%
future_dates = df_house_test[['ds']]
forecast = model.predict(future_dates)

forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(7)
# Out:
#                      ds      yhat  yhat_lower  yhat_upper
# 329 2012-12-30 20:30:00  1.056108    0.272923    1.871167
# 330 2012-12-30 21:00:00  1.095366    0.252412    1.853762
# 331 2012-12-30 21:30:00  1.095395    0.322125    1.855471
# 332 2012-12-30 22:00:00  1.058946    0.292079    1.805171
# 333 2012-12-30 22:30:00  0.993279    0.184464    1.753357
# 334 2012-12-30 23:00:00  0.908365    0.124975    1.706268
# 335 2012-12-30 23:30:00  0.814722    0.033234    1.530713

# %%
fc = forecast[['ds', 'yhat']].rename(columns = {'Date': 'ds', 'Forecast': 'yhat'})

# %% [markdown]
# #### visualizing predictions

# %%
model.plot(forecast);

# %%
x = model.plot_components(forecast)

# %%
forecast[['ds', 'yhat']]
results = df_house_test[['ds', 'y']].merge(forecast[['ds', 'yhat']], on = 'ds')

# %%
results.head(5)

# %%
plt.figure()
x = plt.plot(results['y'], 'b')
x = plt.plot(results['yhat'], 'r')
plt.show()

# %%
np.sqrt(mean_squared_error(results['y'], results['yhat']))
